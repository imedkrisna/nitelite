# %% [markdown]
# # Appendix: Tim

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
from IPython.display import display

# %%
BASE_DIR = Path(r"C:\Users\timot\Downloads\forecast_results_20251126_1056")

assert BASE_DIR.exists(), "Results directory not found."

excel_files = sorted(BASE_DIR.glob("*.xlsx"))

print(f"Number of Excel files detected: {len(excel_files)}")
for f in excel_files:
    print("-", f.name)
# Out:
# Number of Excel files detected: 16
# - ARDL_baseline.xlsx
# - ARDL_covid.xlsx
# - ARDL_q.xlsx
# - ARDL_q_covid.xlsx
# - ARDL_q_scar.xlsx
# - ARDL_scar.xlsx
# - model_summary.xlsx
# - VECM_baseline.xlsx
# - VECM_covid.xlsx
# - VECM_q.xlsx
# - VECM_q_covid.xlsx
# - VECM_q_scar.xlsx
# - VECM_scar.xlsx
# - ~$ARDL_baseline.xlsx
# - ~$ARDL_q_scar.xlsx
# - ~$model_summary.xlsx

# %%
BASE_DIR = Path(r"C:\Users\timot\Downloads\forecast_results_20251126_1056")

assert BASE_DIR.exists(), "Results directory not found."

excel_files = sorted([
    f for f in BASE_DIR.glob("*.xlsx")
    if not f.name.startswith("~$")
])

print(f"Number of Excel files detected: {len(excel_files)}")
for f in excel_files:
    print("-", f.name)
# Out:
# Number of Excel files detected: 13
# - ARDL_baseline.xlsx
# - ARDL_covid.xlsx
# - ARDL_q.xlsx
# - ARDL_q_covid.xlsx
# - ARDL_q_scar.xlsx
# - ARDL_scar.xlsx
# - model_summary.xlsx
# - VECM_baseline.xlsx
# - VECM_covid.xlsx
# - VECM_q.xlsx
# - VECM_q_covid.xlsx
# - VECM_q_scar.xlsx
# - VECM_scar.xlsx

# %%
for file_path in excel_files:
    render_excel_results(file_path)
# Out:
# ...
# RESULT FILE: ARDL_baseline.xlsx
# ...
#
# --------------------------------------------------------------------------------
# Sheet: Forecast_vs_Actual
# --------------------------------------------------------------------------------
#   Unnamed: 0  g_forecast   g_actual    error
# 0 2025-09-30   15.056096  15.052376  0.00372
# --------------------------------------------------------------------------------
# Sheet: Fit_Stats
# --------------------------------------------------------------------------------
#   Model Specification  Steps_ahead      MAE     RMSE   Train_end
# 0  ARDL      baseline            1  0.00372  0.00372  2025-06-30
# --------------------------------------------------------------------------------
# Sheet: Model_Coefficients
# --------------------------------------------------------------------------------
#   variable    coef  std err      z  P>|z|  [0.025  0.975]
# 0    const  2.7538    1.606  1.714  0.094  -0.495   6.003
# ...

# %% [markdown]
# ## Reproducibility
#
# This appendix is fully reproducible:
# - All tables are loaded directly from model output files
# - No manual modification of results is performed
# - Updating results only requires replacing the Excel files
#
# This design ensures auditability and consistency with institutional standards.
